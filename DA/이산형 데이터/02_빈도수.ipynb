# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 생성
data = np.random.randint(1,7, size=100)
print(data)

# 빈도수 계산
unique, counts = np.unique(data, return_counts=True)
# Out:
# [4 1 4 6 3 4 6 2 2 4 4 4 1 6 3 1 3 4 2 6 2 4 4 3 4 2 3 1 2 6 5 4 4 3 6 4 6
#  2 6 5 2 1 6 4 4 4 5 3 1 6 3 4 6 1 5 6 3 6 2 1 3 2 3 6 1 3 4 2 5 2 1 3 5 5
#  2 6 1 4 4 6 5 3 4 5 4 3 5 5 4 4 3 2 5 5 1 3 3 1 2 2]

# %%
# 막대 그래프 시각화
fig, ax = plt.subplots()
ax.bar(unique, counts)
ax.set_xlabel('Value')
ax.set_ylabel('Frequency')
ax.set_title('Frequency Distribution')
plt.show()
